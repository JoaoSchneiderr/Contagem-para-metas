# %% [markdown]
# **Análise Exploratória de Dados**
#
# *utilizando a base de acidentes de trânsito da Polícia Rodoviária Federal (PRF) referentes ao ano de 2025.*

# %%
import pandas as pd

# Carregar o arquivo SQL no Google Colab
df = pd.read_csv('C:\Users\joao.schneider_limbe\Downloads\acidentes.csv')

# Visualizar as primeiras linhas do DataFrame
print(df.head())

# Obter estatísticas descritivas dos dados
print(df.describe())

# Plotar um gráfico de barras
df['coluna'].value_counts().plot(kind='bar')
# Out:
#   File "/tmp/ipykernel_363/2694293793.py", line 4
#     df = pd.read_csv('C:\Users\joao.schneider_limbe\Downloads\acidentes.csv')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
